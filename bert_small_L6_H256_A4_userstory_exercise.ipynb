# %% [markdown]
# <a href="https://colab.research.google.com/github/barkhahbpp/sistem-cerdas/blob/main/bert_small_L6_H256_A4_userstory_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 Install Dependencies #

# %%
# !pip install tensorflow_text
# Out:
# Collecting tensorflow_text
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_text) (0.15.0)
# Collecting tensorflow<2.16,>=2.15.0 (from tensorflow_text)
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.59.2)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow<2.16,>=2.15.0->tensorflow_text)
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 109.2 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15.0->tensorflow_text)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 46.9 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15.0->tensorflow_text)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 95.1 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow, tensorflow_text
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# Successfully installed keras-2.15.0 tensorboard-2.15.1 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow_text-2.15.0

# %% [markdown]
# # 2 Data #

# %% [markdown]
# ## 2.1 Loading Data ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataseturl = 'https://raw.githubusercontent.com/barkhahbpp/deepsedataset/main/sp_dataset/marked_data/moodle.csv'
userstory_df = pd.read_csv(dataseturl)
userstory_df
# Out:
#        issuekey                                              title  \
# 0      MDL-1626                 Forum: Per-discussion subscription
# 1      MDL-3714                             Forum: Reply by e-mail
# 2      MDL-5583  allow teachers to specify certain fields in da...
# 3      MDL-8501                 Forum: proceed to next thread link
# 4     MDL-10115  A use profile's course list is arbitarily limi...
# ...         ...                                                ...
# 1161  MDL-54984  Final deprecation / removal of MUC stuff depre...
# 1162  MDL-54988  Final deprecation of methods from lib/modinfol...
# 1163  MDL-55066  Create a script to compare all grades for a 57...
# 1164  MDL-55126  Deprecated get_records_csv() and put_records_c...
# 1165  MDL-55173                    Forum final deprecations to 2.8
#
#                                             description  storypoint split_mark
# 0     I am finding that my inbox is absolutely flood...         100      train
# 1     How about the ability to post to the forums vi...         100      train
# 2     When creating a database, allow the teacher to...          20      train
# 3     Please put a link to jump to the next thread i...          20      train
# 4     When viewing a user's profile, if the list of ...          13      train
# ...                                                 ...         ...        ...
# 1161  From [~mr-russ], in devs chat:    {quote}  As ...           1       test
# 1162  I found is_user_access_restricted_by_group(), ...           1       test
# 1163  Currently the upgrade step for checking if a c...           2       test
# 1164  While searching for php 7.1 incompatible code ...           1       test
# 1165  Perform final deprecations for all forum funct...           1       test
#
# [1166 rows x 5 columns]

# %%
userstory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   issuekey     1166 non-null   object
#  1   title        1166 non-null   object
#  2   description  1166 non-null   object
#  3   storypoint   1166 non-null   int64
#  4   split_mark   1166 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 45.7+ KB

# %% [markdown]
# ## 2.2 Explanatory Data Analisys ##

# %% [markdown]
# ### 2.2.1 Splitting Strategy Overview

# %% [markdown]
# Overviewing split strategy according to dataset. Dataset author split dataset into three category split marks. first, test set, second, train set and third, validation set.

# %%
split_strategy = userstory_df.groupby('split_mark').agg('count')
split_strategy['sum'] = split_strategy['issuekey'].sum()
split_strategy['percent'] = (split_strategy['issuekey']/split_strategy['issuekey'].sum()*100)

split_strategy['datacount'] = split_strategy['issuekey']
split_strategy = split_strategy.drop(['issuekey',	'title',	'description',	'storypoint'], axis=1)
split_strategy
# Out:
#              sum    percent  datacount
# split_mark
# test        1166  20.068611        234
# train       1166  59.948542        699
# val         1166  19.982847        233

# %%
# Split Strategy Overview
fig, axes = plt.subplots(ncols=2, figsize=(12, 4), dpi=100)
plt.tight_layout()

split_strategy['datacount'].plot(ax=axes[0],kind="pie", autopct="%.1f%%")
split_strategy['datacount'].plot(ax=axes[1],kind="bar")

for container in axes[1].containers:
  axes[1].bar_label(container)

axes[0].set_title('Split Set Strategy (Percentage)', fontsize=13)
axes[1].set_title('Number of Data per Split Mark', fontsize=13)

plt.show()
# fig, axes = plt.subplots(ncols=2, figsize=(17, 4), dpi=100)

# %% [markdown]
# ### 2.2.2 Descriptive Analysis of Dataset ###

# %% [markdown]
# Generate descriptive statistic of dataset. Information about number of character and number of token from dataset will be calculated and evaluated

# %%
# calculate number of token and character from the text
# number of character
userstory_df['numofchars'] = userstory_df['title'].str.len()

# number of word tokens
userstory_df['numofwords'] = userstory_df['title'].str.split().map(lambda x: len(x))
userstory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   issuekey     1166 non-null   object
#  1   title        1166 non-null   object
#  2   description  1166 non-null   object
#  3   storypoint   1166 non-null   int64
#  4   split_mark   1166 non-null   object
#  5   numofchars   1166 non-null   int64
#  6   numofwords   1166 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 63.9+ KB

# %%
userstory_df
# Out:
#        issuekey                                              title  \
# 0      MDL-1626                 Forum: Per-discussion subscription
# 1      MDL-3714                             Forum: Reply by e-mail
# 2      MDL-5583  allow teachers to specify certain fields in da...
# 3      MDL-8501                 Forum: proceed to next thread link
# 4     MDL-10115  A use profile's course list is arbitarily limi...
# ...         ...                                                ...
# 1161  MDL-54984  Final deprecation / removal of MUC stuff depre...
# 1162  MDL-54988  Final deprecation of methods from lib/modinfol...
# 1163  MDL-55066  Create a script to compare all grades for a 57...
# 1164  MDL-55126  Deprecated get_records_csv() and put_records_c...
# 1165  MDL-55173                    Forum final deprecations to 2.8
#
#                                             description  storypoint  \
# 0     I am finding that my inbox is absolutely flood...         100
# 1     How about the ability to post to the forums vi...         100
# 2     When creating a database, allow the teacher to...          20
# 3     Please put a link to jump to the next thread i...          20
# 4     When viewing a user's profile, if the list of ...          13
# ...                                                 ...         ...
# 1161  From [~mr-russ], in devs chat:    {quote}  As ...           1
# 1162  I found is_user_access_restricted_by_group(), ...           1
# 1163  Currently the upgrade step for checking if a c...           2
# 1164  While searching for php 7.1 incompatible code ...           1
# 1165  Perform final deprecations for all forum funct...           1
#
#      split_mark  numofchars  numofwords
# 0         train          34           3
# 1         train          22           4
# 2         train          73          11
# 3         train          34           6
# 4         train          85          15
# ...         ...         ...         ...
# 1161       test          58          10
# 1162       test          52           6
# 1163       test          72          13
# 1164       test          50           4
# 1165       test          31           5
#
# [1166 rows x 7 columns]

# %%
userstory_df.describe().transpose()
# Out:
#              count       mean        std   min   25%   50%   75%    max
# storypoint  1166.0  15.538593  21.645639   1.0   3.0   8.0  20.0  100.0
# numofchars  1166.0  56.014580  19.981080  15.0  43.0  53.0  67.0  158.0
# numofwords  1166.0   8.596055   3.376864   2.0   6.0   8.0  11.0   24.0

# %% [markdown]
# ### 2.2.3 Distribution

# %% [markdown]
# Probability Distribution of number of characters data, number of words data, and story point data.

# %%
import seaborn as sns

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))

sns.histplot(userstory_df.numofchars.map(lambda x: np.mean(x)), ax=ax1, color="red", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Number of Character')

sns.histplot(userstory_df.numofwords.map(lambda x: np.mean(x)), ax=ax2, color="blue", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Number of Words')

fig.suptitle('Average Characters and Words in every User Story')

plt.show()
# userstory_df['storypoint'].plot(kind='hist', bins=20, title='storypoint')
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
fig,ax=plt.subplots(1,1,figsize=(10,5))

sns.histplot(userstory_df.storypoint.map(lambda x: np.mean(x)), ax=ax, color="green", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax.set_title('Story Point')

plt.show()

# %% [markdown]
# ## 2.3 Splitting Dataset ##

# %% [markdown]
# This section will explain splitting dataset according to three splitmark category namely test, train and validation.

# %%
test_df = userstory_df[userstory_df['split_mark']=='test']
print("test_df dimention :"+str(test_df.shape))

train_df = userstory_df[userstory_df['split_mark']=='train']
print("train_df dimention :"+str(train_df.shape))

val_df = userstory_df[userstory_df['split_mark']=='val']
print("val_df dimention :"+str(val_df.shape))
# Out:
# test_df dimention :(234, 7)
# train_df dimention :(699, 7)
# val_df dimention :(233, 7)

# %% [markdown]
# ### 2.3.1 Distribution of Number of Characters of Every Dataset ###

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(17,5))

sns.histplot(train_df.numofchars.map(lambda x: np.mean(x)), ax=ax1, color="magenta", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Train Data Number of Characters')

sns.histplot(test_df.numofchars.map(lambda x: np.mean(x)), ax=ax2, color="navy", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Test Data Number of Characters')

sns.histplot(val_df.numofchars.map(lambda x: np.mean(x)), ax=ax3, color="violet", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax3.set_title('Validation Data Number of Characters')

plt.show()

# %% [markdown]
# ### 2.3.2 Distribution of Number of Words of Every Dataset ###

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(17,5))

sns.histplot(train_df.numofwords.map(lambda x: np.mean(x)), ax=ax1, color="magenta", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Train Data Number of Words')

sns.histplot(test_df.numofwords.map(lambda x: np.mean(x)), ax=ax2, color="navy", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Test Data Number of Words')

sns.histplot(val_df.numofwords.map(lambda x: np.mean(x)), ax=ax3, color="violet", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax3.set_title('Validation Data Number of Words')

plt.show()

# %% [markdown]
# ### 2.3.3 Distribution of Number of Story Point of Every Dataset ###

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(17,5))

sns.histplot(train_df.storypoint.map(lambda x: np.mean(x)), ax=ax1, color="magenta", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Train Data Number of Story Point')

sns.histplot(test_df.storypoint.map(lambda x: np.mean(x)), ax=ax2, color="navy", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Test Data Number of Story Point')

sns.histplot(val_df.storypoint.map(lambda x: np.mean(x)), ax=ax3, color="violet", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax3.set_title('Validation Data Number of Story Point')

plt.show()

# %% [markdown]
# # 3 Model #

# %% [markdown]
# ## 3.1 Build BERT Base Model ##

# %%
import tensorflow_hub as hub
import tensorflow_text as text
import tensorflow as tf
from tensorflow.keras import optimizers

# %%
# preprocess_url = 'https://kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/en-uncased-preprocess/versions/3'
# encoder_url = 'https://www.kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/en-uncased-l-12-h-768-a-12/versions/4'

preprocess_url = 'https://kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/en-uncased-preprocess/versions/3'
encoder_url = 'https://www.kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/bert-en-uncased-l-6-h-256-a-4/versions/2'

# Loading Preprocessor and Encoder Model
preprocessor = hub.KerasLayer(preprocess_url)
encoder = hub.KerasLayer(encoder_url, trainable=True)

# %%
# BERT Model
text_input_layer = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
encoder_inputs = preprocessor(text_input_layer)
outputs = encoder(encoder_inputs)

# Multilayer Perceptron Model
layer = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
layer = tf.keras.layers.Dense(8, activation='relu', name='hidden1')(layer)
layer = tf.keras.layers.Dense(6, activation='relu', name='hidden2')(layer)
layer = tf.keras.layers.Dense(6, activation='sigmoid', name='hidden3')(layer)
layer = tf.keras.layers.Dense(1, name='output')(layer)

#Final Model
model = tf.keras.Model(inputs=[text_input_layer], outputs=[layer])

# %%
tf.keras.utils.plot_model(model, show_shapes=True, expand_nested=True, dpi=48)

# %% [markdown]
# ## 3.2 Define Model Metric ##

# %%
METRICS = [
      tf.keras.metrics.MeanAbsoluteError(name='MAE'),
      tf.keras.metrics.RootMeanSquaredError(name='RMSE')
]

initial_rate = 0.1
end_rate = 0.001
decay_steps = 10000

learning_rate_fn = optimizers.schedules.PolynomialDecay(
    initial_rate,
    decay_steps,
    end_rate,
    power=0.5)

model.compile(loss='mean_absolute_error',
              optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_fn),
              metrics=METRICS)

# %% [markdown]
# ## 3.3 Train Model

# %% [markdown]
# ### 3.3.1 Fit Model ###

# %%
history = model.fit(train_df['title'], train_df['storypoint'],
                    epochs=100,
                    batch_size=15,
                    verbose=1,
                    validation_data=(train_df['title'], train_df['storypoint']))
# Out:
# Epoch 1/100
# 47/47 [==============================] - 42s 631ms/step - loss: 13.4838 - MAE: 13.4838 - RMSE: 25.4103 - val_loss: 12.9929 - val_MAE: 12.9929 - val_RMSE: 24.3419
# Epoch 2/100
# 47/47 [==============================] - 28s 601ms/step - loss: 12.9483 - MAE: 12.9483 - RMSE: 24.6648 - val_loss: 12.8593 - val_MAE: 12.8593 - val_RMSE: 24.7717
# Epoch 3/100
# 47/47 [==============================] - 28s 603ms/step - loss: 12.8685 - MAE: 12.8685 - RMSE: 24.7712 - val_loss: 12.8655 - val_MAE: 12.8655 - val_RMSE: 24.7504
# Epoch 4/100
# 47/47 [==============================] - 28s 608ms/step - loss: 12.8710 - MAE: 12.8710 - RMSE: 24.7748 - val_loss: 12.9203 - val_MAE: 12.9203 - val_RMSE: 24.5684
# Epoch 5/100
# 47/47 [==============================] - 28s 600ms/step - loss: 12.8846 - MAE: 12.8846 - RMSE: 24.7484 - val_loss: 12.8923 - val_MAE: 12.8923 - val_RMSE: 24.6604
# Epoch 6/100
# 47/47 [==============================] - 28s 610ms/step - loss: 12.8650 - MAE: 12.8650 - RMSE: 24.8018 - val_loss: 12.8576 - val_MAE: 12.8576 - val_RMSE: 24.8603
# Epoch 7/100
# 47/47 [==============================] - 28s 593ms/step - loss: 12.8941 - MAE: 12.8941 - RMSE: 24.7866 - val_loss: 12.8576 - val_MAE: 12.8576 - val_RMSE: 24.8603
# Epoch 8/100
# 47/47 [==============================] - 28s 608ms/step - loss: 12.8858 - MAE: 12.8858 - RMSE: 24.8263 - val_loss: 12.8926 - val_MAE: 12.8926 - val_RMSE: 24.6591
# Epoch 9/100
# 47/47 [==============================] - 28s 609ms/step - loss: 12.9213 - MAE: 12.9213 - RMSE: 24.6376 - val_loss: 12.8762 - val_MAE: 12.8762 - val_RMSE: 24.7142
# Epoch 10/100
# 47/47 [==============================] - 29s 611ms/step - loss: 12.8632 - MAE: 12.8632 - RMSE: 24.8121 - val_loss: 12.8628 - val_MAE: 12.8628 - val_RMSE: 24.8687
# Epoch 11/100
# 47/47 [==============================] - 28s 604ms/step - loss: 12.8551 - MAE: 12.8551 - RMSE: 24.8235 - val_loss: 12.8531 - val_MAE: 12.8531 - val_RMSE: 24.7927
# Epoch 12/100
# 47/47 [==============================] - 28s 597ms/step - loss: 12.8551 - MAE: 12.8551 - RMSE: 24.8099 - val_loss: 12.8558 - val_MAE: 12.8558 - val_RMSE: 24.8574
# Epoch 92/100
# 47/47 [==============================] - 28s 592ms/step - loss: 12.8603 - MAE: 12.8603 - RMSE: 24.7840 - val_loss: 12.8473 - val_MAE: 12.8473 - val_RMSE: 24.8130
# Epoch 93/100
# 47/47 [==============================] - 27s 581ms/step - loss: 12.8832 - MAE: 12.8832 - RMSE: 24.7932 - val_loss: 12.8449 - val_MAE: 12.8449 - val_RMSE: 24.8399
# Epoch 94/100
# 47/47 [==============================] - 28s 589ms/step - loss: 12.8683 - MAE: 12.8683 - RMSE: 24.7855 - val_loss: 12.8538 - val_MAE: 12.8538 - val_RMSE: 24.7903
# Epoch 95/100
# 47/47 [==============================] - 27s 577ms/step - loss: 12.8547 - MAE: 12.8547 - RMSE: 24.8123 - val_loss: 12.8594 - val_MAE: 12.8594 - val_RMSE: 24.8633
# Epoch 96/100
# 47/47 [==============================] - 28s 589ms/step - loss: 12.8712 - MAE: 12.8712 - RMSE: 24.8153 - val_loss: 12.8678 - val_MAE: 12.8678 - val_RMSE: 24.7424
# Epoch 97/100
# 47/47 [==============================] - 27s 575ms/step - loss: 12.8817 - MAE: 12.8817 - RMSE: 24.7671 - val_loss: 12.8607 - val_MAE: 12.8607 - val_RMSE: 24.8653
# Epoch 98/100
# 47/47 [==============================] - 28s 590ms/step - loss: 12.8762 - MAE: 12.8762 - RMSE: 24.7174 - val_loss: 12.8576 - val_MAE: 12.8576 - val_RMSE: 24.7774
# Epoch 99/100
# 47/47 [==============================] - 27s 575ms/step - loss: 12.8722 - MAE: 12.8722 - RMSE: 24.7728 - val_loss: 12.8493 - val_MAE: 12.8493 - val_RMSE: 24.8061
# Epoch 100/100
# 47/47 [==============================] - 28s 594ms/step - loss: 12.8513 - MAE: 12.8513 - RMSE: 24.8170 - val_loss: 12.8467 - val_MAE: 12.8467 - val_RMSE: 24.8428

# %% [markdown]
# ### 3.3.2 Training Curve ###

# %%
fig, (axs1, axs2) = plt.subplots(1,2,figsize=(15,5))

loss = {
    'training_loss': history.history['loss'],
    'validation_loss': history.history['val_loss']
}

rmse = {
    'training_rmse': history.history['RMSE'],
    'validation_rmse': history.history['val_RMSE']
}

sns.lineplot(loss, ax=axs1, linestyle='solid')
sns.lineplot(rmse, ax=axs2, linestyle='solid')
fig.suptitle("Training Curve")

plt.show()

# %% [markdown]
# ## 3.4 Predict Story Point ##

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

pred = model.predict(test_df['title'])

mae = mean_absolute_error(test_df['storypoint'], pred)
mse = mean_squared_error(test_df['storypoint'], pred)
rmse = np.sqrt(mse)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)

print("\n pred vs actual :\n")

actualsp = test_df['storypoint'].to_numpy()

for i in range(len(pred)):
  print("pred :"+str(pred[i])+" actual: "+str(actualsp[i])+"\n")
# Out:
# 8/8 [==============================] - 2s 250ms/step
# Results of sklearn.metrics:
# MAE: 6.474263284960363
# MSE: 80.16141010936815
# RMSE: 8.953290462694046
#
#  pred vs actual :
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 20
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 40
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 8
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 13
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 5
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 4
#
# pred :[7.976484] actual: 3
#
# pred :[7.976484] actual: 4
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 2
#
# pred :[7.976484] actual: 1
#
# pred :[7.976484] actual: 1
