# %% [markdown]
# <a href="https://colab.research.google.com/github/barkhahbpp/sistem-cerdas/blob/main/bert_small_L6_H512_A8_userstory_reg_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **STORY POINT ESTIMATION BERT_SMALL_L6_H512_A8**
#
# Nama : Barkhah Pudya Permana
#
# NIM : 22/509244/PTK/14895

# %% [markdown]
# # 1 Install Dependencies #

# %%
# !pip install tensorflow_text
# Out:
# Collecting tensorflow_text
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_text) (0.15.0)
# Collecting tensorflow<2.16,>=2.15.0 (from tensorflow_text)
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow_text) (1.59.2)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow<2.16,>=2.15.0->tensorflow_text)
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 97.5 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15.0->tensorflow_text)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 45.5 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15.0->tensorflow_text)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 97.3 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow_text) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow, tensorflow_text
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# Successfully installed keras-2.15.0 tensorboard-2.15.1 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow_text-2.15.0

# %%
# !pip install pyyaml h5py
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)

# %% [markdown]
# # 2 Data #

# %% [markdown]
# ## 2.1 Loading Data ##

# %%
import os

import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(tf.version.VERSION)
# Out:
# 2.15.0

# %%
dataseturl = 'https://raw.githubusercontent.com/barkhahbpp/deepsedataset/main/sp_dataset/marked_data/moodle.csv'
userstory_df = pd.read_csv(dataseturl)
userstory_df
# Out:
#        issuekey                                              title  \
# 0      MDL-1626                 Forum: Per-discussion subscription
# 1      MDL-3714                             Forum: Reply by e-mail
# 2      MDL-5583  allow teachers to specify certain fields in da...
# 3      MDL-8501                 Forum: proceed to next thread link
# 4     MDL-10115  A use profile's course list is arbitarily limi...
# ...         ...                                                ...
# 1161  MDL-54984  Final deprecation / removal of MUC stuff depre...
# 1162  MDL-54988  Final deprecation of methods from lib/modinfol...
# 1163  MDL-55066  Create a script to compare all grades for a 57...
# 1164  MDL-55126  Deprecated get_records_csv() and put_records_c...
# 1165  MDL-55173                    Forum final deprecations to 2.8
#
#                                             description  storypoint split_mark
# 0     I am finding that my inbox is absolutely flood...         100      train
# 1     How about the ability to post to the forums vi...         100      train
# 2     When creating a database, allow the teacher to...          20      train
# 3     Please put a link to jump to the next thread i...          20      train
# 4     When viewing a user's profile, if the list of ...          13      train
# ...                                                 ...         ...        ...
# 1161  From [~mr-russ], in devs chat:    {quote}  As ...           1       test
# 1162  I found is_user_access_restricted_by_group(), ...           1       test
# 1163  Currently the upgrade step for checking if a c...           2       test
# 1164  While searching for php 7.1 incompatible code ...           1       test
# 1165  Perform final deprecations for all forum funct...           1       test
#
# [1166 rows x 5 columns]

# %%
userstory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   issuekey     1166 non-null   object
#  1   title        1166 non-null   object
#  2   description  1166 non-null   object
#  3   storypoint   1166 non-null   int64
#  4   split_mark   1166 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 45.7+ KB

# %% [markdown]
# ## 2.2 Exploratory Data Analisys ##

# %% [markdown]
# ### 2.2.1 Splitting Strategy Overview

# %% [markdown]
# Overviewing split strategy according to dataset. Dataset author split dataset into three category split marks. first, test set, second, train set and third, validation set.

# %%
split_strategy = userstory_df.groupby('split_mark').agg('count')
split_strategy['sum'] = split_strategy['issuekey'].sum()
split_strategy['percent'] = (split_strategy['issuekey']/split_strategy['issuekey'].sum()*100)

split_strategy['datacount'] = split_strategy['issuekey']
split_strategy = split_strategy.drop(['issuekey',	'title',	'description',	'storypoint'], axis=1)
split_strategy
# Out:
#              sum    percent  datacount
# split_mark
# test        1166  20.068611        234
# train       1166  59.948542        699
# val         1166  19.982847        233

# %%
# Split Strategy Overview
fig, axes = plt.subplots(ncols=2, figsize=(12, 4), dpi=100)
plt.tight_layout()

split_strategy['datacount'].plot(ax=axes[0],kind="pie", autopct="%.1f%%")
split_strategy['datacount'].plot(ax=axes[1],kind="bar")

for container in axes[1].containers:
  axes[1].bar_label(container)

axes[0].set_title('Split Set Strategy (Percentage)', fontsize=13)
axes[1].set_title('Number of Data per Split Mark', fontsize=13)

plt.show()
# fig, axes = plt.subplots(ncols=2, figsize=(17, 4), dpi=100)

# %% [markdown]
# ### 2.2.2 Descriptive Analysis of Dataset ###

# %% [markdown]
# Generate descriptive statistic of dataset. Information about number of character and number of token from dataset will be calculated and evaluated

# %%
# calculate number of token and character from the text
# number of character
userstory_df['numofchars'] = userstory_df['title'].str.len()

# number of word tokens
userstory_df['numofwords'] = userstory_df['title'].str.split().map(lambda x: len(x))
userstory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1166 entries, 0 to 1165
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   issuekey     1166 non-null   object
#  1   title        1166 non-null   object
#  2   description  1166 non-null   object
#  3   storypoint   1166 non-null   int64
#  4   split_mark   1166 non-null   object
#  5   numofchars   1166 non-null   int64
#  6   numofwords   1166 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 63.9+ KB

# %%
userstory_df
# Out:
#        issuekey                                              title  \
# 0      MDL-1626                 Forum: Per-discussion subscription
# 1      MDL-3714                             Forum: Reply by e-mail
# 2      MDL-5583  allow teachers to specify certain fields in da...
# 3      MDL-8501                 Forum: proceed to next thread link
# 4     MDL-10115  A use profile's course list is arbitarily limi...
# ...         ...                                                ...
# 1161  MDL-54984  Final deprecation / removal of MUC stuff depre...
# 1162  MDL-54988  Final deprecation of methods from lib/modinfol...
# 1163  MDL-55066  Create a script to compare all grades for a 57...
# 1164  MDL-55126  Deprecated get_records_csv() and put_records_c...
# 1165  MDL-55173                    Forum final deprecations to 2.8
#
#                                             description  storypoint  \
# 0     I am finding that my inbox is absolutely flood...         100
# 1     How about the ability to post to the forums vi...         100
# 2     When creating a database, allow the teacher to...          20
# 3     Please put a link to jump to the next thread i...          20
# 4     When viewing a user's profile, if the list of ...          13
# ...                                                 ...         ...
# 1161  From [~mr-russ], in devs chat:    {quote}  As ...           1
# 1162  I found is_user_access_restricted_by_group(), ...           1
# 1163  Currently the upgrade step for checking if a c...           2
# 1164  While searching for php 7.1 incompatible code ...           1
# 1165  Perform final deprecations for all forum funct...           1
#
#      split_mark  numofchars  numofwords
# 0         train          34           3
# 1         train          22           4
# 2         train          73          11
# 3         train          34           6
# 4         train          85          15
# ...         ...         ...         ...
# 1161       test          58          10
# 1162       test          52           6
# 1163       test          72          13
# 1164       test          50           4
# 1165       test          31           5
#
# [1166 rows x 7 columns]

# %%
userstory_df.describe().transpose()
# Out:
#              count       mean        std   min   25%   50%   75%    max
# storypoint  1166.0  15.538593  21.645639   1.0   3.0   8.0  20.0  100.0
# numofchars  1166.0  56.014580  19.981080  15.0  43.0  53.0  67.0  158.0
# numofwords  1166.0   8.596055   3.376864   2.0   6.0   8.0  11.0   24.0

# %% [markdown]
# ### 2.2.3 Distribution

# %% [markdown]
# Probability Distribution of number of characters data, number of words data, and story point data.

# %%
import seaborn as sns

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))

sns.histplot(userstory_df.numofchars.map(lambda x: np.mean(x)), ax=ax1, color="red", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Number of Character')

sns.histplot(userstory_df.numofwords.map(lambda x: np.mean(x)), ax=ax2, color="blue", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Number of Words')

fig.suptitle('Average Characters and Words in every User Story')

plt.show()
# userstory_df['storypoint'].plot(kind='hist', bins=20, title='storypoint')
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
fig,ax=plt.subplots(1,1,figsize=(10,5))

sns.histplot(userstory_df.storypoint.map(lambda x: np.mean(x)), ax=ax, color="green", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax.set_title('Story Point')

plt.show()

# %% [markdown]
# ## 2.3 Splitting Dataset ##

# %% [markdown]
# This section will explain splitting dataset according to three splitmark category namely test, train and validation.

# %%
from sklearn.model_selection import train_test_split

test_df = userstory_df[userstory_df['split_mark']=='test']
print("test_df dimention :"+str(test_df.shape))

train_df = userstory_df[userstory_df['split_mark']=='train']
print("train_df dimention :"+str(train_df.shape))

val_df = userstory_df[userstory_df['split_mark']=='val']
print("val_df dimention :"+str(val_df.shape))

X_val, X_test, y_val, y_test = train_test_split(train_df['title'], train_df['storypoint'], test_size=0.6, random_state=4)
# Out:
# test_df dimention :(234, 7)
# train_df dimention :(699, 7)
# val_df dimention :(233, 7)

# %% [markdown]
# ### 2.3.1 Distribution of Number of Characters of Every Dataset ###

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(17,5))

sns.histplot(train_df.numofchars.map(lambda x: np.mean(x)), ax=ax1, color="magenta", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Train Data Number of Characters')

sns.histplot(test_df.numofchars.map(lambda x: np.mean(x)), ax=ax2, color="navy", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Test Data Number of Characters')

sns.histplot(val_df.numofchars.map(lambda x: np.mean(x)), ax=ax3, color="violet", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax3.set_title('Validation Data Number of Characters')

plt.show()

# %% [markdown]
# ### 2.3.2 Distribution of Number of Words of Every Dataset ###

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(17,5))

sns.histplot(train_df.numofwords.map(lambda x: np.mean(x)), ax=ax1, color="magenta", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Train Data Number of Words')

sns.histplot(test_df.numofwords.map(lambda x: np.mean(x)), ax=ax2, color="navy", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Test Data Number of Words')

sns.histplot(val_df.numofwords.map(lambda x: np.mean(x)), ax=ax3, color="violet", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax3.set_title('Validation Data Number of Words')

plt.show()

# %% [markdown]
# ### 2.3.3 Distribution of Number of Story Point of Every Dataset ###

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(17,5))

sns.histplot(train_df.storypoint.map(lambda x: np.mean(x)), ax=ax1, color="magenta", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax1.set_title('Train Data Number of Story Point')

sns.histplot(test_df.storypoint.map(lambda x: np.mean(x)), ax=ax2, color="navy", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax2.set_title('Test Data Number of Story Point')

sns.histplot(val_df.storypoint.map(lambda x: np.mean(x)), ax=ax3, color="violet", kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4))
ax3.set_title('Validation Data Number of Story Point')

plt.show()

# %% [markdown]
# # 3 Model #

# %% [markdown]
# ## 3.1 Build Small BERT Model ##

# %%
import tensorflow_hub as hub
import tensorflow_text as text
from tensorflow.keras import optimizers

# %%
# preprocess_url = 'https://kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/en-uncased-preprocess/versions/3'
# encoder_url = 'https://www.kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/en-uncased-l-12-h-768-a-12/versions/4'

preprocess_url = 'https://kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/en-uncased-preprocess/versions/3'
encoder_url = 'https://www.kaggle.com/models/tensorflow/bert/frameworks/TensorFlow2/variations/bert-en-uncased-l-6-h-512-a-8/versions/2'

# Loading Preprocessor and Encoder Model
preprocessor = hub.KerasLayer(preprocess_url)
encoder = hub.KerasLayer(encoder_url, trainable=True)

# %%
# BERT Model
text_input_layer = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
encoder_inputs = preprocessor(text_input_layer)
outputs = encoder(encoder_inputs)

# Multilayer Perceptron Model
layer = tf.keras.layers.Dropout(0.4, name="dropout")(outputs['pooled_output'])
layer = tf.keras.layers.Dense(128, activation='relu', name='hidden1')(layer)
layer = tf.keras.layers.Dense(128, activation='relu', name='hidden2')(layer)
layer = tf.keras.layers.Dense(128, activation='relu', name='hidden3')(layer)
layer = tf.keras.layers.Dense(128, activation='relu', name='hidden4')(layer)
layer = tf.keras.layers.Dense(1, activation='linear', name='output')(layer)

#Final Model
model = tf.keras.Model(inputs=[text_input_layer], outputs=[layer])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  keras_layer (KerasLayer)    {'input_word_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_type_ids': (None,
#                               128)}
#
#  keras_layer_1 (KerasLayer)  {'sequence_output': (None,   3506841   ['keras_layer[0][0]',
#                               128, 512),                  7          'keras_layer[0][1]',
#                               'encoder_outputs': [(None              'keras_layer[0][2]']
#                              , 128, 512),
#                               (None, 128, 512),
#                               (None, 128, 512),
#                               (None, 128, 512),
#                               (None, 128, 512),
#                               (None, 128, 512)],
#                               'pooled_output': (None, 5
#                              12),
#                               'default': (None, 512)}
#
#  dropout (Dropout)           (None, 512)                  0         ['keras_layer_1[0][7]']
#
#  hidden1 (Dense)             (None, 128)                  65664     ['dropout[0][0]']
#
#  hidden2 (Dense)             (None, 128)                  16512     ['hidden1[0][0]']
#
#  hidden3 (Dense)             (None, 128)                  16512     ['hidden2[0][0]']
#
#  hidden4 (Dense)             (None, 128)                  16512     ['hidden3[0][0]']
#
#  output (Dense)              (None, 1)                    129       ['hidden4[0][0]']
#
# ==================================================================================================
# Total params: 35183746 (134.22 MB)
# Trainable params: 35183745 (134.22 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, expand_nested=True, dpi=48)

# %% [markdown]
# ## 3.2 Define Model Metric ##

# %%
METRICS = [
      tf.keras.metrics.MeanAbsoluteError(name='MAE'),
      tf.keras.metrics.RootMeanSquaredError(name='RMSE')
]

initial_rate = 0.0001
end_rate = 1e-8
decay_steps = 10000

learning_rate_fn = optimizers.schedules.PolynomialDecay(
    initial_rate,
    decay_steps,
    end_rate,
    power=0.5)

model.compile(loss='mean_absolute_error',
              optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate_fn),
              metrics=METRICS)

# %% [markdown]
# ## 3.3 Train Model

# %% [markdown]
# ### 3.3.1 Fit Model ###

# %%
pwd
# Out:
# '/content'

# %%
checkpoint_path = "bert_small_L6_H256_A4_userstory_exercise/Checkpoint-{epoch:02d}-{MAE:.02f}.h5"
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, monitor='loss', verbose=1, save_best_only=True, mode='min')
history = model.fit(train_df['title'], train_df['storypoint'],
                    epochs=1000,
                    batch_size=25,
                    verbose=1,
                    validation_data=(X_val, y_val),
                    callbacks=[checkpoint])
# Out:
# Epoch 1/1000
# 28/28 [==============================] - ETA: 0s - loss: 16.9192 - MAE: 16.9192 - RMSE: 28.5954
# Epoch 1: loss improved from inf to 16.91919, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-01-16.92.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 28/28 [==============================] - 68s 2s/step - loss: 16.9192 - MAE: 16.9192 - RMSE: 28.5954 - val_loss: 16.4627 - val_MAE: 16.4627 - val_RMSE: 28.0748
# Epoch 2/1000
# 28/28 [==============================] - ETA: 0s - loss: 16.6937 - MAE: 16.6937 - RMSE: 28.4762
# Epoch 2: loss improved from 16.91919 to 16.69373, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-02-16.69.h5
# 28/28 [==============================] - 61s 2s/step - loss: 16.6937 - MAE: 16.6937 - RMSE: 28.4762 - val_loss: 16.1980 - val_MAE: 16.1980 - val_RMSE: 27.9203
# Epoch 3/1000
# 28/28 [==============================] - ETA: 0s - loss: 16.4211 - MAE: 16.4211 - RMSE: 28.2969
# Epoch 3: loss improved from 16.69373 to 16.42110, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-03-16.42.h5
# 28/28 [==============================] - 60s 2s/step - loss: 16.4211 - MAE: 16.4211 - RMSE: 28.2969 - val_loss: 15.9125 - val_MAE: 15.9125 - val_RMSE: 27.7569
# Epoch 4/1000
# 28/28 [==============================] - ETA: 0s - loss: 16.1313 - MAE: 16.1313 - RMSE: 28.1180
# Epoch 4: loss improved from 16.42110 to 16.13134, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-04-16.13.h5
# 28/28 [==============================] - 60s 2s/step - loss: 16.1313 - MAE: 16.1313 - RMSE: 28.1180 - val_loss: 15.6096 - val_MAE: 15.6096 - val_RMSE: 27.5797
# Epoch 5/1000
# 28/28 [==============================] - ETA: 0s - loss: 15.8184 - MAE: 15.8184 - RMSE: 27.9395
# Epoch 5: loss improved from 16.13134 to 15.81839, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-05-15.82.h5
# 28/28 [==============================] - 59s 2s/step - loss: 15.8184 - MAE: 15.8184 - RMSE: 27.9395 - val_loss: 15.2606 - val_MAE: 15.2606 - val_RMSE: 27.3746
# Epoch 6/1000
# 28/28 [==============================] - ETA: 0s - loss: 15.4895 - MAE: 15.4895 - RMSE: 27.7335
# Epoch 6: loss improved from 15.81839 to 15.48949, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-06-15.49.h5
# 28/28 [==============================] - 60s 2s/step - loss: 15.4895 - MAE: 15.4895 - RMSE: 27.7335 - val_loss: 14.8859 - val_MAE: 14.8859 - val_RMSE: 27.1515
# Epoch 7/1000
# 28/28 [==============================] - ETA: 0s - loss: 15.1312 - MAE: 15.1312 - RMSE: 27.4909
# Epoch 7: loss improved from 15.48949 to 15.13120, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-07-15.13.h5
# 28/28 [==============================] - 60s 2s/step - loss: 15.1312 - MAE: 15.1312 - RMSE: 27.4909 - val_loss: 14.5619 - val_MAE: 14.5619 - val_RMSE: 26.9162
# Epoch 8/1000
# 28/28 [==============================] - ETA: 0s - loss: 14.8203 - MAE: 14.8203 - RMSE: 27.2803
# Epoch 8: loss improved from 15.13120 to 14.82028, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-08-14.82.h5
# 28/28 [==============================] - 60s 2s/step - loss: 14.8203 - MAE: 14.8203 - RMSE: 27.2803 - val_loss: 14.2277 - val_MAE: 14.2277 - val_RMSE: 26.6713
# Epoch 9/1000
# 28/28 [==============================] - ETA: 0s - loss: 14.5197 - MAE: 14.5197 - RMSE: 27.0148
# Epoch 9: loss improved from 14.82028 to 14.51974, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-09-14.52.h5
# 28/28 [==============================] - 59s 2s/step - loss: 14.5197 - MAE: 14.5197 - RMSE: 27.0148 - val_loss: 13.9799 - val_MAE: 13.9799 - val_RMSE: 26.4287
# Epoch 10/1000
# 28/28 [==============================] - ETA: 0s - loss: 14.2539 - MAE: 14.2539 - RMSE: 26.7751
# Epoch 10: loss improved from 14.51974 to 14.25392, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint
1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9750 - MAE: 12.9750 - RMSE: 24.9917
# Epoch 19: loss improved from 13.05289 to 12.97501, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-19-12.98.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.9750 - MAE: 12.9750 - RMSE: 24.9917 - val_loss: 12.7361 - val_MAE: 12.7361 - val_RMSE: 24.5303
# Epoch 20/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9784 - MAE: 12.9784 - RMSE: 24.9519
# Epoch 20: loss did not improve from 12.97501
# 28/28 [==============================] - 59s 2s/step - loss: 12.9784 - MAE: 12.9784 - RMSE: 24.9519 - val_loss: 12.7015 - val_MAE: 12.7015 - val_RMSE: 24.4446
# Epoch 21/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9979 - MAE: 12.9979 - RMSE: 24.9535
# Epoch 21: loss did not improve from 12.97501
# 28/28 [==============================] - 59s 2s/step - loss: 12.9979 - MAE: 12.9979 - RMSE: 24.9535 - val_loss: 12.6947 - val_MAE: 12.6947 - val_RMSE: 24.4162
# Epoch 22/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9626 - MAE: 12.9626 - RMSE: 24.8582
# Epoch 22: loss improved from 12.97501 to 12.96257, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-22-12.96.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.9626 - MAE: 12.9626 - RMSE: 24.8582 - val_loss: 12.6975 - val_MAE: 12.6975 - val_RMSE: 24.3765
# Epoch 23/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9333 - MAE: 12.9333 - RMSE: 24.7969
# Epoch 23: loss improved from 12.96257 to 12.93327, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-23-12.93.h5
# 28/28 [==============================] - 61s 2s/step - loss: 12.9333 - MAE: 12.9333 - RMSE: 24.7969 - val_loss: 12.6992 - val_MAE: 12.6992 - val_RMSE: 24.3560
# Epoch 24/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8916 - MAE: 12.8916 - RMSE: 24.8031
# Epoch 24: loss improved from 12.93327 to 12.89157, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-24-12.89.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.8916 - MAE: 12.8916 - RMSE: 24.8031 - val_loss: 12.7029 - val_MAE: 12.7029 - val_RMSE: 24.3311
# Epoch 25/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9654 - MAE: 12.9654 - RMSE: 24.8263
# Epoch 25: loss did not improve from 12.89157
# 28/28 [==============================] - 60s 2s/step - loss: 12.9654 - MAE: 12.9654 - RMSE: 24.8263 - val_loss: 12.7083 - val_MAE: 12.7083 - val_RMSE: 24.3188
# Epoch 26/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9449 - MAE: 12.9449 - RMSE: 24.7873
# Epoch 26: loss did not improve from 12.89157
# 28/28 [==============================] - 60s 2s/step - loss: 12.9449 - MAE: 12.9449 - RMSE: 24.7873 - val_loss: 12.7103 - val_MAE: 12.7103 - val_RMSE: 24.3055
# Epoch 27/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9098 - MAE: 12.9098 - RMSE: 24.7492
# Epoch 27: loss did not improve from 12.89157
# 28/28 [==============================] - 59s 2s/step - loss: 12.9098 - MAE: 12.9098 - RMSE: 24.7492 - val_loss: 12.7104 - val_MAE: 12.7104 - val_RMSE: 24.3010
# Epoch 28/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9240 - MAE: 12.9240 - RMSE: 24.7468
# Epoch 28: loss did not improve from 12.89157
# 28/28 [==============================] - 59s 2s/step - loss: 12.9240 - MAE: 12.9240 - RMSE: 24.7468 - val_loss: 12.7122 - val_MAE: 12.7122 - val_RMSE: 24.2913
# Epoch 29/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.
1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8664 - MAE: 12.8664 - RMSE: 24.7226
# Epoch 39: loss did not improve from 12.86553
# 28/28 [==============================] - 59s 2s/step - loss: 12.8664 - MAE: 12.8664 - RMSE: 24.7226 - val_loss: 12.6819 - val_MAE: 12.6819 - val_RMSE: 24.2441
# Epoch 40/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8936 - MAE: 12.8936 - RMSE: 24.7219
# Epoch 40: loss did not improve from 12.86553
# 28/28 [==============================] - 59s 2s/step - loss: 12.8936 - MAE: 12.8936 - RMSE: 24.7219 - val_loss: 12.6717 - val_MAE: 12.6717 - val_RMSE: 24.2521
# Epoch 41/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.9220 - MAE: 12.9220 - RMSE: 24.7968
# Epoch 41: loss did not improve from 12.86553
# 28/28 [==============================] - 59s 2s/step - loss: 12.9220 - MAE: 12.9220 - RMSE: 24.7968 - val_loss: 12.6612 - val_MAE: 12.6612 - val_RMSE: 24.2541
# Epoch 42/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8455 - MAE: 12.8455 - RMSE: 24.7119
# Epoch 42: loss improved from 12.86553 to 12.84545, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-42-12.85.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.8455 - MAE: 12.8455 - RMSE: 24.7119 - val_loss: 12.6591 - val_MAE: 12.6591 - val_RMSE: 24.2444
# Epoch 43/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8865 - MAE: 12.8865 - RMSE: 24.7589
# Epoch 43: loss did not improve from 12.84545
# 28/28 [==============================] - 59s 2s/step - loss: 12.8865 - MAE: 12.8865 - RMSE: 24.7589 - val_loss: 12.6691 - val_MAE: 12.6691 - val_RMSE: 24.2296
# Epoch 44/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8661 - MAE: 12.8661 - RMSE: 24.7016
# Epoch 44: loss did not improve from 12.84545
# 28/28 [==============================] - 59s 2s/step - loss: 12.8661 - MAE: 12.8661 - RMSE: 24.7016 - val_loss: 12.6592 - val_MAE: 12.6592 - val_RMSE: 24.2247
# Epoch 45/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8804 - MAE: 12.8804 - RMSE: 24.7307
# Epoch 45: loss did not improve from 12.84545
# 28/28 [==============================] - 59s 2s/step - loss: 12.8804 - MAE: 12.8804 - RMSE: 24.7307 - val_loss: 12.6507 - val_MAE: 12.6507 - val_RMSE: 24.2187
# Epoch 46/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8428 - MAE: 12.8428 - RMSE: 24.7176
# Epoch 46: loss improved from 12.84545 to 12.84278, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-46-12.84.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.8428 - MAE: 12.8428 - RMSE: 24.7176 - val_loss: 12.6391 - val_MAE: 12.6391 - val_RMSE: 24.2219
# Epoch 47/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8948 - MAE: 12.8948 - RMSE: 24.7413
# Epoch 47: loss did not improve from 12.84278
# 28/28 [==============================] - 61s 2s/step - loss: 12.8948 - MAE: 12.8948 - RMSE: 24.7413 - val_loss: 12.6194 - val_MAE: 12.6194 - val_RMSE: 24.2186
# Epoch 48/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8534 - MAE: 12.8534 - RMSE: 24.7163
# Epoch 48: loss did not improve from 12.84278
# 28/28 [==============================] - 59s 2s/step - loss: 12.8534 - MAE: 12.8534 - RMSE: 24.7163 - val_loss: 12.6196 - val_MAE: 12.6196 - val_RMSE: 24.1884
# Epoch 49/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8233 - MAE: 12.8233 - RMSE: 24.6873
# Epoch 49: loss improved from 12.84278 to 12.82327, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-49-12.82.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.8233 - MAE: 12.8233 - RMSE: 24.6873 - val_loss: 12.6106 - val_MAE: 12.6106 - val_RMSE: 24.1632
# Epoch 50/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8262 - MAE: 12.8262 - RMSE: 24.6646
# Epoch 50: loss did not improve from 12.82327
# 28/28 [==============================] - 59s 2s/step - loss: 12.8262 - MAE: 12.8262 - RMSE: 24.6646 - val_loss: 12.6417 - val_MAE: 12.6417 - val_RMSE: 24.1121
# Epoch 51/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8060 - MAE: 12.8060 - RMSE: 24.6700
# Epoch 51: loss improved from 12.82327 to 12.80599, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-51-12.81.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.8060 - MAE: 12.8060 - RMSE: 24.6700 - val_loss: 12.5842 - val_MAE: 12.5842 - val_RMSE: 24.1319
# Epoch 52/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8390 - MAE: 12.8390 - RMSE: 24.7176
# Epoch 52: loss did not improve from 12.80599
# 28/28 [==============================] - 60s 2s/step - loss: 12.8390 - MAE: 12.8390 - RMSE: 24.7176 - val_loss: 12.5937 - val_MAE: 12.5937 - val_RMSE: 24.0943
# Epoch 53/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8359 - MAE: 12.8359 - RMSE: 24.6955
# Epoch 53: loss did not improve from 12.80599
# 28/28 [==============================] - 59s 2s/step - loss: 12.8359 - MAE: 12.8359 - RMSE: 24.6955 - val_loss: 12.6038 - val_MAE: 12.6038 - val_RMSE: 24.0596
# Epoch 54/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8340 - MAE: 12.8340 - RMSE: 24.6764
# Epoch 54: loss did not improve from 12.80599
# 28/28 [==============================] - 60s 2s/step - loss: 12.8340 - MAE: 12.8340 - RMSE: 24.6764 - val_loss: 12.5556 - val_MAE: 12.5556 - val_RMSE: 24.0719
# Epoch 55/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7984 - MAE: 12.7984 - RMSE: 24.6623
# Epoch 55: loss improved from 12.80599 to 12.79845, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-55-12.80.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.7984 - MAE: 12.7984 - RMSE: 24.6623 - val_loss: 12.5539 - val_MAE: 12.5539 - val_RMSE: 24.0622
# Epoch 56/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7560 - MAE: 12.7560 - RMSE: 24.5743
# Epoch 56: loss improved from 12.79845 to 12.75604, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-56-12.76.h5
# 28/28 [==============================] - 61s 2s/step - loss: 12.7560 - MAE: 12.7560 - RMSE: 24.5743 - val_loss: 12.5097 - val_MAE: 12.5097 - val_RMSE: 24.0706
# Epoch 57/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.8168 - MAE: 12.8168 - RMSE: 24.5716
# Epoch 57: loss did not improve from 12.75604
# 28/28 [==============================] - 60s 2s/step - loss: 12.8168 - MAE: 12.8168 - RMSE: 24.5716 - val_loss: 12.5074 - val_MAE: 12.5074 - val_RMSE: 24.0455
# Epoch 58/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7314 - MAE: 12.7314 - RMSE: 24.5942
# Epoch 58: loss improved from 12.75604 to 12.73139, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-58-12.73.h5
# 28/28 [==============================] - 61s 2s/step - loss: 12.7314 - MAE: 12.7314 - RMSE: 24.5942 - val_loss: 12.5155 - val_MAE: 12.5155 - val_RMSE: 23.9982
# Epoch 59/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7767 - MAE: 12.7767 - RMSE: 24.5465
# Epoch 59: loss did not improve from 12.73139
# 28/28 [==============================] - 60s 2s/step - loss: 12.7767 - MAE: 12.7767 - RMSE: 24.5465 - val_loss: 12.4497 - val_MAE: 12.4497 - val_RMSE: 24.0341
# Epoch 60/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7447 - MAE: 12.7447 - RMSE: 24.6306
# Epoch 60: loss did not improve from 12.73139
# 28/28 [==============================] - 60s 2s/step - loss: 12.7447 - MAE: 12.7447 - RMSE: 24.6306 - val_loss: 12.4357 - val_MAE: 12.4357 - val_RMSE: 24.0048
# Epoch 61/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7333 - MAE: 12.7333 - RMSE: 24.6009
# Epoch 61: loss did not improve from 12.73139
# 28/28 [==============================] - 59s 2s/step - loss: 12.7333 - MAE: 12.7333 - RMSE: 24.6009 - val_loss: 12.4761 - val_MAE: 12.4761 - val_RMSE: 23.9289
# Epoch 62/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7173 - MAE: 12.7173 - RMSE: 24.4873
# Epoch 62: loss improved from 12.73139 to 12.71732, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-62-12.72.h5
# 28/28 [==============================] - 59s 2s/step - loss: 12.7173 - MAE: 12.7173 - RMSE: 24.4873 - val_loss: 12.4796 - val_MAE: 12.4796 - val_RMSE: 23.8758
# Epoch 63/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.7444 - MAE: 12.7444 - RMSE: 24.5708
# Epoch 63: loss did not improve from 12.71732
# 28/28 [==============================] - 59s 2s/step - loss: 12.7444 - MAE: 12.7444 - RMSE: 24.5708 - val_loss: 12.4427 - val_MAE: 12.4427 - val_RMSE: 23.8579
# Epoch 64/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.6723 - MAE: 12.6723 - RMSE: 24.4140
# Epoch 64: loss improved from 12.71732 to 12.67227, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-64-12.67.h5
# 28/28 [==============================] - 59s 2s/step - loss: 12.6723 - MAE: 12.6723 - RMSE: 24.4140 - val_loss: 12.3637 - val_MAE: 12.3637 - val_RMSE: 23.8839
# Epoch 65/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.6743 - MAE: 12.6743 - RMSE: 24.4277
# Epoch 65: loss did not improve from 12.67227
# 28/28 [==============================] - 60s 2s/step - loss: 12.6743 - MAE: 12.6743 - RMSE: 24.4277 - val_loss: 12.3093 - val_MAE: 12.3093 - val_RMSE: 23.9544
# Epoch 66/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.6234 - MAE: 12.6234 - RMSE: 24.4791
# Epoch 66: loss improved from 12.67227 to 12.62343, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-66-12.62.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.6234 - MAE: 12.6234 - RMSE: 24.4791 - val_loss: 12.4218 - val_MAE: 12.4218 - val_RMSE: 23.7604
# Epoch 67/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.6293 - MAE: 12.6293 - RMSE: 24.3814
# Epoch 67: loss did not improve from 12.62343
# 28/28 [==============================] - 60s 2s/step - loss: 12.6293 - MAE: 12.6293 - RMSE: 24.3814 - val_loss: 12.3065 - val_MAE: 12.3065 - val_RMSE: 23.8144
# Epoch 68/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.5952 - MAE: 12.5952 - RMSE: 24.4437
# Epoch 68: loss improved from 12.62343 to 12.59517, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-68-12.60.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.5952 - MAE: 12.5952 - RMSE: 24.4437 - val_loss: 12.2459 - val_MAE: 12.2459 - val_RMSE: 23.8668
# Epoch 69/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.5874 - MAE: 12.5874 - RMSE: 24.4401
# Epoch 69: loss improved from 12.59517 to 12.58737, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-69-12.59.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.5874 - MAE: 12.5874 - RMSE: 24.4401 - val_loss: 12.2151 - val_MAE: 12.2151 - val_RMSE: 23.8537
# Epoch 70/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.5580 - MAE: 12.5580 - RMSE: 24.3743
# Epoch 70: loss improved from 12.58737 to 12.55798, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-70-12.56.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.5580 - MAE: 12.5580 - RMSE: 24.3743 - val_loss: 12.1930 - val_MAE: 12.1930 - val_RMSE: 23.7878
# Epoch 71/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.5882 - MAE: 12.5882 - RMSE: 24.3839
# Epoch 71: loss did not improve from 12.55798
# 28/28 [==============================] - 60s 2s/step - loss: 12.5882 - MAE: 12.5882 - RMSE: 24.3839 - val_loss: 12.2006 - val_MAE: 12.2006 - val_RMSE: 23.7180
# Epoch 72/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.5584 - MAE: 12.5584 - RMSE: 24.3494
# Epoch 72: loss did not improve from 12.55798
# 28/28 [==============================] - 60s 2s/step - loss: 12.5584 - MAE: 12.5584 - RMSE: 24.3494 - val_loss: 12.1774 - val_MAE: 12.1774 - val_RMSE: 23.6916
# Epoch 73/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.5176 - MAE: 12.5176 - RMSE: 24.3367
# Epoch 73: loss improved from 12.55798 to 12.51765, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-73-12.52.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.5176 - MAE: 12.5176 - RMSE: 24.3367 - val_loss: 12.1279 - val_MAE: 12.1279 - val_RMSE: 23.6780
# Epoch 74/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.5012 - MAE: 12.5012 - RMSE: 24.3687
# Epoch 74: loss improved from 12.51765 to 12.50118, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-74-12.50.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.5012 - MAE: 12.5012 - RMSE: 24.3687 - val_loss: 12.0668 - val_MAE: 12.0668 - val_RMSE: 23.7601
# Epoch 75/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.4649 - MAE: 12.4649 - RMSE: 24.3058
# Epoch 75: loss improved from 12.50118 to 12.46494, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-75-12.46.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.4649 - MAE: 12.4649 - RMSE: 24.3058 - val_loss: 12.0370 - val_MAE: 12.0370 - val_RMSE: 23.6603
# Epoch 76/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.4622 - MAE: 12.4622 - RMSE: 24.1898
# Epoch 76: loss improved from 12.46494 to 12.46224, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-76-12.46.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.4622 - MAE: 12.4622 - RMSE: 24.1898 - val_loss: 12.0002 - val_MAE: 12.0002 - val_RMSE: 23.6056
# Epoch 77/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.4144 - MAE: 12.4144 - RMSE: 24.1882
# Epoch 77: loss improved from 12.46224 to 12.41440, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-77-12.41.h5
# 28/28 [==============================] - 59s 2s/step - loss: 12.4144 - MAE: 12.4144 - RMSE: 24.1882 - val_loss: 12.0164 - val_MAE: 12.0164 - val_RMSE: 23.4569
# Epoch 78/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.4117 - MAE: 12.4117 - RMSE: 24.1633
# Epoch 78: loss improved from 12.41440 to 12.41168, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-78-12.41.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.4117 - MAE: 12.4117 - RMSE: 24.1633 - val_loss: 11.9410 - val_MAE: 11.9410 - val_RMSE: 23.4628
# Epoch 79/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.4195 - MAE: 12.4195 - RMSE: 24.0721
# Epoch 79: loss did not improve from 12.41168
# 28/28 [==============================] - 59s 2s/step - loss: 12.4195 - MAE: 12.4195 - RMSE: 24.0721 - val_loss: 11.9045 - val_MAE: 11.9045 - val_RMSE: 23.4172
# Epoch 80/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.3902 - MAE: 12.3902 - RMSE: 24.0184
# Epoch 80: loss improved from 12.41168 to 12.39024, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-80-12.39.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.3902 - MAE: 12.3902 - RMSE: 24.0184 - val_loss: 11.8222 - val_MAE: 11.8222 - val_RMSE: 23.4628
# Epoch 81/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.3654 - MAE: 12.3654 - RMSE: 24.0906
# Epoch 81: loss improved from 12.39024 to 12.36542, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-81-12.37.h5
# 28/28 [==============================] - 59s 2s/step - loss: 12.3654 - MAE: 12.3654 - RMSE: 24.0906 - val_loss: 11.7762 - val_MAE: 11.7762 - val_RMSE: 23.3979
# Epoch 82/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.2971 - MAE: 12.2971 - RMSE: 23.9833
# Epoch 82: loss improved from 12.36542 to 12.29714, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-82-12.30.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.2971 - MAE: 12.2971 - RMSE: 23.9833 - val_loss: 11.7804 - val_MAE: 11.7804 - val_RMSE: 23.2653
# Epoch 83/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.2819 - MAE: 12.2819 - RMSE: 23.9667
# Epoch 83: loss improved from 12.29714 to 12.28193, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-83-12.28.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.2819 - MAE: 12.2819 - RMSE: 23.9667 - val_loss: 11.6746 - val_MAE: 11.6746 - val_RMSE: 23.3537
# Epoch 84/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.2450 - MAE: 12.2450 - RMSE: 23.9537
# Epoch 84: loss improved from 12.28193 to 12.24501, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-84-12.25.h5
# 28/28 [==============================] - 59s 2s/step - loss: 12.2450 - MAE: 12.2450 - RMSE: 23.9537 - val_loss: 11.6103 - val_MAE: 11.6103 - val_RMSE: 23.3385
# Epoch 85/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.1568 - MAE: 12.1568 - RMSE: 23.8013
# Epoch 85: loss improved from 12.24501 to 12.15681, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-85-12.16.h5
# 28/28 [==============================] - 60s 2s/step - loss: 12.1568 - MAE: 12.1568 - RMSE: 23.8013 - val_loss: 11.5670 - val_MAE: 11.5670 - val_RMSE: 23.1872
# Epoch 86/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.1048 - MAE: 12.1048 - RMSE: 23.7062
# Epoch 86: loss improved from 12.15681 to 12.10479, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-86-12.10.h5
# 28/28 [==============================] - 59s 2s/step - loss: 12.1048 - MAE: 12.1048 - RMSE: 23.7062 - val_loss: 11.5832 - val_MAE: 11.5832 - val_RMSE: 23.0542
# Epoch 87/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.1650 - MAE: 12.1650 - RMSE: 23.7665
# Epoch 87: loss did not improve from 12.10479
# 28/28 [==============================] - 59s 2s/step - loss: 12.1650 - MAE: 12.1650 - RMSE: 23.7665 - val_loss: 11.4269 - val_MAE: 11.4269 - val_RMSE: 23.1050
# Epoch 88/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.0457 - MAE: 12.0457 - RMSE: 23.6311
# Epoch 88: loss improved from 12.10479 to 12.04573, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-88-12.05.h5
# 28/28 [==============================] - 59s 2s/step - loss: 12.0457 - MAE: 12.0457 - RMSE: 23.6311 - val_loss: 11.4210 - val_MAE: 11.4210 - val_RMSE: 22.9527
# Epoch 89/1000
# 28/28 [==============================] - ETA: 0s - loss: 12.0821 - MAE: 12.0821 - RMSE: 23.8434
# Epoch 89: loss did not improve from 12.04573
# 28/28 [==============================] - 58s 2s/step - loss: 12.0821 - MAE: 12.0821 - RMSE: 23.8434 - val_loss: 11.3648 - val_MAE: 11.3648 - val_RMSE: 22.8804
# Epoch 90/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.9733 - MAE: 11.9733 - RMSE: 23.6379
# Epoch 90: loss improved from 12.04573 to 11.97326, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-90-11.97.h5
# 28/28 [==============================] - 59s 2s/step - loss: 11.9733 - MAE: 11.9733 - RMSE: 23.6379 - val_loss: 11.4207 - val_MAE: 11.4207 - val_RMSE: 22.7506
# Epoch 91/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.8471 - MAE: 11.8471 - RMSE: 23.6439
# Epoch 91: loss improved from 11.97326 to 11.84707, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-91-11.85.h5
# 28/28 [==============================] - 59s 2s/step - loss: 11.8471 - MAE: 11.8471 - RMSE: 23.6439 - val_loss: 11.5141 - val_MAE: 11.5141 - val_RMSE: 22.6320
# Epoch 92/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.8689 - MAE: 11.8689 - RMSE: 23.5487
# Epoch 92: loss did not improve from 11.84707
# 28/28 [==============================] - 59s 2s/step - loss: 11.8689 - MAE: 11.8689 - RMSE: 23.5487 - val_loss: 11.0492 - val_MAE: 11.0492 - val_RMSE: 22.9803
# Epoch 93/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.8232 - MAE: 11.8232 - RMSE: 23.3926
# Epoch 93: loss improved from 11.84707 to 11.82323, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-93-11.82.h5
# 28/28 [==============================] - 59s 2s/step - loss: 11.8232 - MAE: 11.8232 - RMSE: 23.3926 - val_loss: 10.9541 - val_MAE: 10.9541 - val_RMSE: 22.6545
# Epoch 94/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.8221 - MAE: 11.8221 - RMSE: 23.5215
# Epoch 94: loss improved from 11.82323 to 11.82206, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-94-11.82.h5
# 28/28 [==============================] - 59s 2s/step - loss: 11.8221 - MAE: 11.8221 - RMSE: 23.5215 - val_loss: 10.8648 - val_MAE: 10.8648 - val_RMSE: 22.6042
# Epoch 95/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.7321 - MAE: 11.7321 - RMSE: 23.3443
# Epoch 95: loss improved from 11.82206 to 11.73212, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-95-11.73.h5
# 28/28 [==============================] - 58s 2s/step - loss: 11.7321 - MAE: 11.7321 - RMSE: 23.3443 - val_loss: 10.7820 - val_MAE: 10.7820 - val_RMSE: 22.5262
# Epoch 96/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.6049 - MAE: 11.6049 - RMSE: 23.2739
# Epoch 96: loss improved from 11.73212 to 11.60495, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-96-11.60.h5
# 28/28 [==============================] - 59s 2s/step - loss: 11.6049 - MAE: 11.6049 - RMSE: 23.2739 - val_loss: 10.6826 - val_MAE: 10.6826 - val_RMSE: 22.4793
# Epoch 97/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.6610 - MAE: 11.6610 - RMSE: 23.3435
# Epoch 97: loss did not improve from 11.60495
# 28/28 [==============================] - 59s 2s/step - loss: 11.6610 - MAE: 11.6610 - RMSE: 23.3435 - val_loss: 10.6008 - val_MAE: 10.6008 - val_RMSE: 22.3883
# Epoch 98/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.5083 - MAE: 11.5083 - RMSE: 23.1379
# Epoch 98: loss improved from 11.60495 to 11.50832, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-98-11.51.h5
# 28/28 [==============================] - 59s 2s/step - loss: 11.5083 - MAE: 11.5083 - RMSE: 23.1379 - val_loss: 10.5748 - val_MAE: 10.5748 - val_RMSE: 22.1896
# Epoch 99/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.4748 - MAE: 11.4748 - RMSE: 23.2935
# Epoch 99: loss improved from 11.50832 to 11.47481, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-99-11.47.h5
# 28/28 [==============================] - 60s 2s/step - loss: 11.4748 - MAE: 11.4748 - RMSE: 23.2935 - val_loss: 10.4169 - val_MAE: 10.4169 - val_RMSE: 22.2128
# Epoch 100/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.3856 - MAE: 11.3856 - RMSE: 23.2242
# Epoch 100: loss improved from 11.47481 to 11.38563, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-100-11.39.h5
# 28/28 [==============================] - 59s 2s/step - loss: 11.3856 - MAE: 11.3856 - RMSE: 23.2242 - val_loss: 10.4049 - val_MAE: 10.4049 - val_RMSE: 22.0113
# Epoch 101/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.3539 - MAE: 11.3539 - RMSE: 22.9054
# Epoch 101: loss improved from 11.38563 to 11.35393, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-101-11.35.h5
# 28/28 [==============================] - 60s 2s/step - loss: 11.3539 - MAE: 11.3539 - RMSE: 22.9054 - val_loss: 10.4174 - val_MAE: 10.4174 - val_RMSE: 21.7925
# Epoch 102/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.3095 - MAE: 11.3095 - RMSE: 22.9833
# Epoch 102: loss improved from 11.35393 to 11.30949, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-102-11.31.h5
# 28/28 [==============================] - 60s 2s/step - loss: 11.3095 - MAE: 11.3095 - RMSE: 22.9833 - val_loss: 10.2021 - val_MAE: 10.2021 - val_RMSE: 21.7556
# Epoch 103/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.2303 - MAE: 11.2303 - RMSE: 22.6620
# Epoch 103: loss improved from 11.30949 to 11.23027, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-103-11.23.h5
# 28/28 [==============================] - 60s 2s/step - loss: 11.2303 - MAE: 11.2303 - RMSE: 22.6620 - val_loss: 10.9311 - val_MAE: 10.9311 - val_RMSE: 21.5439
# Epoch 104/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.2255 - MAE: 11.2255 - RMSE: 22.6612
# Epoch 104: loss improved from 11.23027 to 11.22548, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-104-11.23.h5
# 28/28 [==============================] - 61s 2s/step - loss: 11.2255 - MAE: 11.2255 - RMSE: 22.6612 - val_loss: 10.0274 - val_MAE: 10.0274 - val_RMSE: 21.5188
# Epoch 105/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.1467 - MAE: 11.1467 - RMSE: 22.6808
# Epoch 105: loss improved from 11.22548 to 11.14667, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-105-11.15.h5
# 28/28 [==============================] - 61s 2s/step - loss: 11.1467 - MAE: 11.1467 - RMSE: 22.6808 - val_loss: 9.8500 - val_MAE: 9.8500 - val_RMSE: 21.7619
# Epoch 106/1000
# 28/28 [==============================] - ETA: 0s - loss: 11.0461 - MAE: 11.0461 - RMSE: 22.4784
# Epoch 106: loss improved from 11.14667 to 11.04606, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-106-11.05.h5
# 28/28 [==============================] - 61s 2s/step - loss: 11.0461 - MAE: 11.0461 - RMSE: 22.4784 - val_loss: 9.7989 - val_MAE: 9.7989 - val_RMSE: 21.8058
# Epoch 107/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.7345 - MAE: 10.7345 - RMSE: 22.2698
# Epoch 107: loss improved from 11.04606 to 10.73453, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-107-10.73.h5
# 28/28 [==============================] - 60s 2s/step - loss: 10.7345 - MAE: 10.7345 - RMSE: 22.2698 - val_loss: 9.8443 - val_MAE: 9.8443 - val_RMSE: 21.0418
# Epoch 108/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.7644 - MAE: 10.7644 - RMSE: 22.1843
# Epoch 108: loss did not improve from 10.73453
# 28/28 [==============================] - 59s 2s/step - loss: 10.7644 - MAE: 10.7644 - RMSE: 22.1843 - val_loss: 9.4810 - val_MAE: 9.4810 - val_RMSE: 21.0868
# Epoch 109/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.7375 - MAE: 10.7375 - RMSE: 22.1596
# Epoch 109: loss did not improve from 10.73453
# 28/28 [==============================] - 59s 2s/step - loss: 10.7375 - MAE: 10.7375 - RMSE: 22.1596 - val_loss: 9.4244 - val_MAE: 9.4244 - val_RMSE: 21.0335
# Epoch 110/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.6884 - MAE: 10.6884 - RMSE: 22.1121
# Epoch 110: loss improved from 10.73453 to 10.68836, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-110-10.69.h5
# 28/28 [==============================] - 60s 2s/step - loss: 10.6884 - MAE: 10.6884 - RMSE: 22.1121 - val_loss: 9.4931 - val_MAE: 9.4931 - val_RMSE: 21.5156
# Epoch 111/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.6428 - MAE: 10.6428 - RMSE: 21.8547
# Epoch 111: loss improved from 10.68836 to 10.64281, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-111-10.64.h5
# 28/28 [==============================] - 59s 2s/step - loss: 10.6428 - MAE: 10.6428 - RMSE: 21.8547 - val_loss: 9.2380 - val_MAE: 9.2380 - val_RMSE: 20.6716
# Epoch 112/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.5990 - MAE: 10.5990 - RMSE: 22.0203
# Epoch 112: loss improved from 10.64281 to 10.59904, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-112-10.60.h5
# 28/28 [==============================] - 59s 2s/step - loss: 10.5990 - MAE: 10.5990 - RMSE: 22.0203 - val_loss: 9.2630 - val_MAE: 9.2630 - val_RMSE: 20.5417
# Epoch 113/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.4898 - MAE: 10.4898 - RMSE: 21.7087
# Epoch 113: loss improved from 10.59904 to 10.48984, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-113-10.49.h5
# 28/28 [==============================] - 59s 2s/step - loss: 10.4898 - MAE: 10.4898 - RMSE: 21.7087 - val_loss: 9.0206 - val_MAE: 9.0206 - val_RMSE: 20.5416
# Epoch 114/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.4452 - MAE: 10.4452 - RMSE: 21.7063
# Epoch 114: loss improved from 10.48984 to 10.44520, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-114-10.45.h5
# 28/28 [==============================] - 60s 2s/step - loss: 10.4452 - MAE: 10.4452 - RMSE: 21.7063 - val_loss: 9.4552 - val_MAE: 9.4552 - val_RMSE: 20.2886
# Epoch 115/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.2107 - MAE: 10.2107 - RMSE: 21.3919
# Epoch 115: loss improved from 10.44520 to 10.21074, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-115-10.21.h5
# 28/28 [==============================] - 60s 2s/step - loss: 10.2107 - MAE: 10.2107 - RMSE: 21.3919 - val_loss: 9.0859 - val_MAE: 9.0859 - val_RMSE: 20.2639
# Epoch 116/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.4166 - MAE: 10.4166 - RMSE: 21.7333
# Epoch 116: loss did not improve from 10.21074
# 28/28 [==============================] - 60s 2s/step - loss: 10.4166 - MAE: 10.4166 - RMSE: 21.7333 - val_loss: 9.0056 - val_MAE: 9.0056 - val_RMSE: 20.1668
# Epoch 117/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.3435 - MAE: 10.3435 - RMSE: 21.6378
# Epoch 117: loss did not improve from 10.21074
# 28/28 [==============================] - 60s 2s/step - loss: 10.3435 - MAE: 10.3435 - RMSE: 21.6378 - val_loss: 8.7797 - val_MAE: 8.7797 - val_RMSE: 20.4400
# Epoch 118/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.1660 - MAE: 10.1660 - RMSE: 21.4748
# Epoch 118: loss improved from 10.21074 to 10.16600, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-118-10.17.h5
# 28/28 [==============================] - 60s 2s/step - loss: 10.1660 - MAE: 10.1660 - RMSE: 21.4748 - val_loss: 8.7325 - val_MAE: 8.7325 - val_RMSE: 20.3968
# Epoch 119/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.0546 - MAE: 10.0546 - RMSE: 21.3525
# Epoch 119: loss improved from 10.16600 to 10.05461, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-119-10.05.h5
# 28/28 [==============================] - 60s 2s/step - loss: 10.0546 - MAE: 10.0546 - RMSE: 21.3525 - val_loss: 8.7930 - val_MAE: 8.7930 - val_RMSE: 20.4359
# Epoch 120/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.2104 - MAE: 10.2104 - RMSE: 21.4072
# Epoch 120: loss did not improve from 10.05461
# 28/28 [==============================] - 59s 2s/step - loss: 10.2104 - MAE: 10.2104 - RMSE: 21.4072 - val_loss: 8.9449 - val_MAE: 8.9449 - val_RMSE: 19.9127
# Epoch 121/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.8784 - MAE: 9.8784 - RMSE: 21.1367
# Epoch 121: loss improved from 10.05461 to 9.87837, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-121-9.88.h5
# 28/28 [==============================] - 60s 2s/step - loss: 9.8784 - MAE: 9.8784 - RMSE: 21.1367 - val_loss: 8.7748 - val_MAE: 8.7748 - val_RMSE: 19.8539
# Epoch 122/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.0295 - MAE: 10.0295 - RMSE: 21.2159
# Epoch 122: loss did not improve from 9.87837
# 28/28 [==============================] - 59s 2s/step - loss: 10.0295 - MAE: 10.0295 - RMSE: 21.2159 - val_loss: 8.8989 - val_MAE: 8.8989 - val_RMSE: 19.8877
# Epoch 123/1000
# 28/28 [==============================] - ETA: 0s - loss: 10.0718 - MAE: 10.0718 - RMSE: 21.3055
# Epoch 123: loss did not improve from 9.87837
# 28/28 [==============================] - 59s 2s/step - loss: 10.0718 - MAE: 10.0718 - RMSE: 21.3055 - val_loss: 8.4665 - val_MAE: 8.4665 - val_RMSE: 19.9837
# Epoch 124/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.7995 - MAE: 9.7995 - RMSE: 21.1409
# Epoch 124: loss improved from 9.87837 to 9.79953, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-124-9.80.h5
# 28/28 [==============================] - 60s 2s/step - loss: 9.7995 - MAE: 9.7995 - RMSE: 21.1409 - val_loss: 8.4258 - val_MAE: 8.4258 - val_RMSE: 19.8315
# Epoch 125/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.7407 - MAE: 9.7407 - RMSE: 20.9273
# Epoch 125: loss improved from 9.79953 to 9.74068, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-125-9.74.h5
# 28/28 [==============================] - 59s 2s/step - loss: 9.7407 - MAE: 9.7407 - RMSE: 20.9273 - val_loss: 8.5498 - val_MAE: 8.5498 - val_RMSE: 20.0418
# Epoch 126/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.7235 - MAE: 9.7235 - RMSE: 20.9770
# Epoch 126: loss improved from 9.74068 to 9.72350, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-126-9.72.h5
# 28/28 [==============================] - 60s 2s/step - loss: 9.7235 - MAE: 9.7235 - RMSE: 20.9770 - val_loss: 9.3286 - val_MAE: 9.3286 - val_RMSE: 19.8372
# Epoch 127/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.8721 - MAE: 9.8721 - RMSE: 20.9885
# Epoch 127: loss did not improve from 9.72350
# 28/28 [==============================] - 59s 2s/step - loss: 9.8721 - MAE: 9.8721 - RMSE: 20.9885 - val_loss: 8.2727 - val_MAE: 8.2727 - val_RMSE: 19.8043
# Epoch 128/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.6569 - MAE: 9.6569 - RMSE: 20.6506
# Epoch 128: loss improved from 9.72350 to 9.65691, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-128-9.66.h5
# 28/28 [==============================] - 60s 2s/step - loss: 9.6569 - MAE: 9.6569 - RMSE: 20.6506 - val_loss: 8.2692 - val_MAE: 8.2692 - val_RMSE: 19.5686
# Epoch 129/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.7026 - MAE: 9.7026 - RMSE: 20.9307
# Epoch 129: loss did not improve from 9.65691
# 28/28 [==============================] - 59s 2s/step - loss: 9.7026 - MAE: 9.7026 - RMSE: 20.9307 - val_loss: 8.2468 - val_MAE: 8.2468 - val_RMSE: 19.5128
# Epoch 130/1000
# 28/28 [==============================] - ETA: 0s - loss: 9.5529 - MAE: 9.5529 - RMSE: 20.8433
# Epoch 130: loss improved from 9.65691 to 9.55292, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-130-9.55.h5
# ...
# 28/28 [==============================] - 59s 2s/step - loss: 4.7080 - MAE: 4.7080 - RMSE: 9.8781 - val_loss: 4.6716 - val_MAE: 4.6716 - val_RMSE: 9.1253
# Epoch 950/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.9450 - MAE: 4.9450 - RMSE: 10.3921
# Epoch 950: loss did not improve from 4.59588
# 28/28 [==============================] - 59s 2s/step - loss: 4.9450 - MAE: 4.9450 - RMSE: 10.3921 - val_loss: 4.6715 - val_MAE: 4.6715 - val_RMSE: 9.1252
# Epoch 951/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.8738 - MAE: 4.8738 - RMSE: 9.9734
# Epoch 951: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 4.8738 - MAE: 4.8738 - RMSE: 9.9734 - val_loss: 4.6719 - val_MAE: 4.6719 - val_RMSE: 9.1255
# Epoch 952/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.7803 - MAE: 4.7803 - RMSE: 9.9260
# Epoch 952: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 4.7803 - MAE: 4.7803 - RMSE: 9.9260 - val_loss: 4.6716 - val_MAE: 4.6716 - val_RMSE: 9.1252
# Epoch 953/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.7233 - MAE: 4.7233 - RMSE: 9.9154
# Epoch 953: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 4.7233 - MAE: 4.7233 - RMSE: 9.9154 - val_loss: 4.6718 - val_MAE: 4.6718 - val_RMSE: 9.1254
# Epoch 954/1000
# 28/28 [==============================] - ETA: 0s - loss: 5.0007 - MAE: 5.0007 - RMSE: 10.0616
# Epoch 954: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 5.0007 - MAE: 5.0007 - RMSE: 10.0616 - val_loss: 4.6716 - val_MAE: 4.6716 - val_RMSE: 9.1252
# Epoch 955/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.9664 - MAE: 4.9664 - RMSE: 10.1417
# Epoch 955: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 4.9664 - MAE: 4.9664 - RMSE: 10.1417 - val_loss: 4.6724 - val_MAE: 4.6724 - val_RMSE: 9.1260
# Epoch 956/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.8962 - MAE: 4.8962 - RMSE: 10.1014
# Epoch 956: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 4.8962 - MAE: 4.8962 - RMSE: 10.1014 - val_loss: 4.6728 - val_MAE: 4.6728 - val_RMSE: 9.1264
# Epoch 957/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.8397 - MAE: 4.8397 - RMSE: 10.1125
# Epoch 957: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 4.8397 - MAE: 4.8397 - RMSE: 10.1125 - val_loss: 4.6726 - val_MAE: 4.6726 - val_RMSE: 9.1263
# Epoch 958/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.9562 - MAE: 4.9562 - RMSE: 10.1525
# Epoch 958: loss did not improve from 4.59588
# 28/28 [==============================] - 60s 2s/step - loss: 4
1000
# 28/28 [==============================] - ETA: 0s - loss: 4.7187 - MAE: 4.7187 - RMSE: 9.8693
# Epoch 996: loss did not improve from 4.59575
# 28/28 [==============================] - 59s 2s/step - loss: 4.7187 - MAE: 4.7187 - RMSE: 9.8693 - val_loss: 4.6733 - val_MAE: 4.6733 - val_RMSE: 9.1264
# Epoch 997/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.7798 - MAE: 4.7798 - RMSE: 10.0211
# Epoch 997: loss did not improve from 4.59575
# 28/28 [==============================] - 60s 2s/step - loss: 4.7798 - MAE: 4.7798 - RMSE: 10.0211 - val_loss: 4.6737 - val_MAE: 4.6737 - val_RMSE: 9.1268
# Epoch 998/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.7438 - MAE: 4.7438 - RMSE: 9.7074
# Epoch 998: loss did not improve from 4.59575
# 28/28 [==============================] - 60s 2s/step - loss: 4.7438 - MAE: 4.7438 - RMSE: 9.7074 - val_loss: 4.6735 - val_MAE: 4.6735 - val_RMSE: 9.1266
# Epoch 999/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.5788 - MAE: 4.5788 - RMSE: 9.5836
# Epoch 999: loss improved from 4.59575 to 4.57881, saving model to bert_small_L6_H256_A4_userstory_exercise/Checkpoint-999-4.58.h5
# 28/28 [==============================] - 60s 2s/step - loss: 4.5788 - MAE: 4.5788 - RMSE: 9.5836 - val_loss: 4.6739 - val_MAE: 4.6739 - val_RMSE: 9.1271
# Epoch 1000/1000
# 28/28 [==============================] - ETA: 0s - loss: 4.6702 - MAE: 4.6702 - RMSE: 9.5033
# Epoch 1000: loss did not improve from 4.57881
# 28/28 [==============================] - 60s 2s/step - loss: 4.6702 - MAE: 4.6702 - RMSE: 9.5033 - val_loss: 4.6737 - val_MAE: 4.6737 - val_RMSE: 9.1268

# %%
# model save
model.save('bert_small_L6_H512_A8_userstory_exercise.keras')

# %% [markdown]
# ### 3.3.2 Training Curve ###

# %%
fig, (axs1, axs2) = plt.subplots(1,2,figsize=(15,5))

loss = {
    'training_loss': history.history['loss'],
    'validation_loss': history.history['val_loss']
}

rmse = {
    'training_rmse': history.history['RMSE'],
    'validation_rmse': history.history['val_RMSE']
}

axs1.plot(loss['training_loss'], label=list(loss.keys())[0])
axs1.plot(loss['validation_loss'], label=list(loss.keys())[1])
axs1.grid(color='grey', linestyle=':', linewidth=1, alpha=0.2)
axs1.legend()

axs2.plot(rmse['training_rmse'], label=list(rmse.keys())[0])
axs2.plot(rmse['validation_rmse'], label=list(rmse.keys())[1])
axs2.grid(color='grey', linestyle=':', linewidth=1, alpha=0.2)
axs2.legend()

axs1.set_xlabel('Epochs')
axs1.set_ylabel('MAE')
axs2.set_xlabel('Epochs')
axs2.set_ylabel('RMSE')

# Adding Research Baseline MAE
axs1.axhline(y=1.16, linewidth=1, linestyle='solid', color='red', label='Fu et al.(2023) w-project')
axs1.axhline(y=2.14, linewidth=1, linestyle='solid', color='violet', label='Fu et al.(2023) x-project')
axs1.legend()

fig.suptitle("Training Curve")

plt.show()

# %% [markdown]
# ## 3.4 Predict Story Point ##

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

pred = model.predict(test_df['title'])

mae = mean_absolute_error(test_df['storypoint'], pred)
mse = mean_squared_error(test_df['storypoint'], pred)
rmse = np.sqrt(mse)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)

print("\n pred vs actual :\n")

actualsp = test_df['storypoint'].to_numpy()

for i in range(len(pred)):
  print("pred :"+str(pred[i])+" actual: "+str(actualsp[i])+"\n")
# Out:
# 8/8 [==============================] - 6s 689ms/step
# Results of sklearn.metrics:
# MAE: 9.10721627718363
# MSE: 162.40696209020638
# RMSE: 12.743899014438492
#
#  pred vs actual :
#
# pred :[27.634218] actual: 20
#
# pred :[8.937315] actual: 20
#
# pred :[21.806576] actual: 5
#
# pred :[8.982736] actual: 8
#
# pred :[38.457024] actual: 40
#
# pred :[45.147324] actual: 40
#
# pred :[38.616104] actual: 20
#
# pred :[4.047034] actual: 5
#
# pred :[8.475853] actual: 5
#
# pred :[25.345469] actual: 5
#
# pred :[11.451845] actual: 5
#
# pred :[24.497583] actual: 5
#
# pred :[10.30295] actual: 13
#
# pred :[3.1257741] actual: 8
#
# pred :[1.8820729] actual: 13
#
# pred :[18.454674] actual: 13
#
# pred :[13.97229] actual: 20
#
# pred :[9.592968] actual: 40
#
# pred :[11.341678] actual: 40
#
# pred :[9.909376] actual: 20
#
# pred :[16.337755] actual: 2
#
# pred :[22.270365] actual: 20
#
# pred :[18.772047] actual: 40
#
# pred :[31.323832] actual: 8
#
# pred :[4.4784346] actual: 5
#
# pred :[3.6878803] actual: 20
#
# pred :[2.5501595] actual: 3
#
# pred :[4.242715] actual: 20
#
# pred :[2.7985153] actual: 3
#
# pred :[15.023781] actual: 20
#
# pred :[28.068134] actual: 13
#
# pred :[12.11179] actual: 20
#
# pred :[17.336792] actual: 8
#
# pred :[2.1919477] actual: 5
#
# pred :[8.925976] actual: 5
#
# pred :[10.800229] actual: 8
#
# pred :[10.57238] actual: 5
#
# pred :[21.089138] actual: 8
#
# pred :[34.226894] actual: 40
#
# pred :[9.917702] actual: 20
#
# pred :[23.679491] actual: 20
#
# pred :[4.8782744] actual: 40
#
# pred :[2.883454] actual: 5
#
# pred :[7.492647] actual: 5
#
# pred :[28.095842] actual: 8
#
# pred :[9.273281] actual: 20
#
# pred :[13.1609745] actual: 40
#
# pred :[6.0258737] actual: 8
#
# pred :[11.25459] actual: 8
#
# pred :[16.065666] actual: 20
#
# pred :[22.222393] actual: 20
#
# pred :[11.899027] actual: 8
#
# pred :[6.8539777] actual: 5
#
# pred :[10.377491] actual: 40
#
# pred :[10.149654] actual: 8
#
# pred :[12.235916] actual: 20
#
# pred :[6.3226337] actual: 5
#
# pred :[12.926025] actual: 2
#
# pred :[22.872377] actual: 20
#
# pred :[13.975605] actual: 13
#
# pred :[6.137693] actual: 20
#
# pred :[10.848014] actual: 20
#
# pred :[5.9881306] actual: 20
#
# pred :[13.242187] actual: 8
#
# pred :[3.6416888] actual: 13
#
# pred :[10.241993] actual: 5
#
# pred :[5.815962] actual: 20
#
# pred :[26.912775] actual: 3
#
# pred :[33.72779] actual: 8
#
# pred :[4.2086906] actual: 8
#
# pred :[24.45864] actual: 5
#
# pred :[3.4472735] actual: 5
#
# pred :[2.3616745] actual: 8
#
# pred :[35.709015] actual: 3
#
# pred :[5.43226] actual: 5
#
# pred :[11.220112] actual: 5
#
# pred :[17.054014] actual: 8
#
# pred :[16.47497] actual: 5
#
# pred :[11.051585] actual: 5
#
# pred :[11.666856] actual: 5
#
# pred :[7.9000444] actual: 5
#
# pred :[50.2379] actual: 8
#
# pred :[2.4021504] actual: 20
#
# pred :[22.319614] actual: 8
#
# pred :[55.80525] actual: 8
#
# pred :[2.42722] actual: 8
#
# pred :[14.492044] actual: 8
#
# pred :[14.417563] actual: 5
#
# pred :[2.0811307] actual: 5
#
# pred :[1.5234209] actual: 8
#
# pred :[2.1229784] actual: 13
#
# pred :[11.795816] actual: 3
#
# pred :[2.831278] actual: 3
#
# pred :[6.407443] actual: 40
#
# pred :[6.187461] actual: 13
#
# pred :[28.222582] actual: 8
#
# pred :[15.573115] actual: 13
#
# pred :[28.694307] actual: 5
#
# pred :[18.432096] actual: 13
#
# pred :[21.747902] actual: 2
#
# pred :[5.1352644] actual: 5
#
# pred :[10.418863] actual: 5
#
# pred :[17.811796] actual: 8
#
# pred :[16.458944] actual: 5
#
# pred :[8.575758] actual: 5
#
# pred :[7.8031178] actual: 5
#
# pred :[5.3992605] actual: 5
#
# pred :[7.9493976] actual: 2
#
# pred :[14.000616] actual: 1
#
# pred :[1.5106301] actual: 3
#
# pred :[16.932953] actual: 13
#
# pred :[27.606825] actual: 8
#
# pred :[1.138344] actual: 1
#
# pred :[28.50249] actual: 5
#
# pred :[11.753002] actual: 13
#
# pred :[3.8457212] actual: 1
#
# pred :[21.411945] actual: 13
#
# pred :[46.2869] actual: 3
#
# pred :[18.292086] actual: 8
#
# pred :[23.36093] actual: 8
#
# pred :[22.974302] actual: 3
#
# pred :[7.8634324] actual: 1
#
# pred :[8.663067] actual: 1
#
# pred :[8.028726] actual: 3
#
# pred :[22.547201] actual: 5
#
# pred :[17.851614] actual: 5
#
# pred :[6.05523] actual: 3
#
# pred :[2.482021] actual: 1
#
# pred :[17.091188] actual: 2
#
# pred :[5.3995304] actual: 1
#
# pred :[12.409372] actual: 1
#
# pred :[5.2364287] actual: 2
#
# pred :[9.309885] actual: 1
#
# pred :[3.54868] actual: 3
#
# pred :[17.941765] actual: 1
#
# pred :[16.28747] actual: 13
#
# pred :[27.148085] actual: 2
#
# pred :[2.3352845] actual: 5
#
# pred :[2.543971] actual: 1
#
# pred :[1.3432628] actual: 3
#
# pred :[16.686613] actual: 1
#
# pred :[38.98855] actual: 3
#
# pred :[14.439891] actual: 2
#
# pred :[1.8191206] actual: 2
#
# pred :[6.012275] actual: 1
#
# pred :[2.3369844] actual: 1
#
# pred :[16.32388] actual: 1
#
# pred :[4.983641] actual: 3
#
# pred :[3.0250697] actual: 3
#
# pred :[15.60496] actual: 1
#
# pred :[17.266825] actual: 3
#
# pred :[18.088396] actual: 1
#
# pred :[13.3590145] actual: 1
#
# pred :[7.840463] actual: 1
#
# pred :[11.381603] actual: 1
#
# pred :[18.932701] actual: 1
#
# pred :[8.184248] actual: 1
#
# pred :[1.8624411] actual: 1
#
# pred :[6.077355] actual: 5
#
# pred :[6.6952915] actual: 1
#
# pred :[7.6740503] actual: 3
#
# pred :[1.8061843] actual: 3
#
# pred :[7.8073907] actual: 2
#
# pred :[3.5601077] actual: 3
#
# pred :[4.991861] actual: 1
#
# pred :[5.615314] actual: 1
#
# pred :[6.717419] actual: 2
#
# pred :[12.30764] actual: 1
#
# pred :[5.5110927] actual: 3
#
# pred :[18.987999] actual: 1
#
# pred :[20.53496] actual: 1
#
# pred :[31.452051] actual: 3
#
# pred :[3.8916926] actual: 1
#
# pred :[2.8359795] actual: 2
#
# pred :[6.2656703] actual: 2
#
# pred :[3.69521] actual: 1
#
# pred :[10.225607] actual: 1
#
# pred :[5.381053] actual: 1
#
# pred :[8.420014] actual: 3
#
# pred :[2.570805] actual: 1
#
# pred :[3.1655462] actual: 1
#
# pred :[6.6481977] actual: 1
#
# pred :[14.931353] actual: 3
#
# pred :[5.7001705] actual: 2
#
# pred :[5.4379587] actual: 3
#
# pred :[9.218933] actual: 2
#
# pred :[5.4752374] actual: 2
#
# pred :[6.40388] actual: 2
#
# pred :[2.5137284] actual: 2
#
# pred :[33.066177] actual: 5
#
# pred :[1.9588497] actual: 2
#
# pred :[6.256019] actual: 3
#
# pred :[3.6226943] actual: 3
#
# pred :[13.8683] actual: 2
#
# pred :[10.190088] actual: 2
#
# pred :[4.5868826] actual: 2
#
# pred :[20.540163] actual: 1
#
# pred :[18.951492] actual: 3
#
# pred :[1.4035547] actual: 1
#
# pred :[5.744909] actual: 1
#
# pred :[3.4221814] actual: 1
#
# pred :[20.756273] actual: 3
#
# pred :[10.624187] actual: 2
#
# pred :[13.414598] actual: 3
#
# pred :[15.500407] actual: 13
#
# pred :[11.352093] actual: 1
#
# pred :[2.4094505] actual: 2
#
# pred :[23.645668] actual: 1
#
# pred :[5.0838184] actual: 1
#
# pred :[5.164924] actual: 1
#
# pred :[8.150277] actual: 3
#
# pred :[18.655706] actual: 2
#
# pred :[4.2460475] actual: 3
#
# pred :[21.622875] actual: 3
#
# pred :[15.341621] actual: 2
#
# pred :[6.565168] actual: 1
#
# pred :[3.2934804] actual: 2
#
# pred :[5.1696415] actual: 1
#
# pred :[27.555304] actual: 2
#
# pred :[2.3831365] actual: 2
#
# pred :[4.814746] actual: 1
#
# pred :[1.3054104] actual: 1
#
# pred :[19.04851] actual: 1
#
# pred :[2.2953026] actual: 3
#
# pred :[14.564201] actual: 5
#
# pred :[5.5430293] actual: 1
#
# pred :[1.9087243] actual: 4
#
# pred :[3.4482987] actual: 3
#
# pred :[10.307295] actual: 4
#
# pred :[4.652639] actual: 1
#
# pred :[1.4113044] actual: 1
#
# pred :[5.9959865] actual: 2
#
# pred :[5.6219115] actual: 1
#
# pred :[4.366008] actual: 1

# %%
fig = plt.figure(figsize=(15,8))

actual = np.array(test_df['storypoint'])
axes = fig.add_subplot()

axes.plot(pred, label="Regression Line")
sns.scatterplot(actual, ax=axes, label="Actual", color='red')

axes.set_xlabel('Index')
axes.set_ylabel('Story Point')
fig.suptitle('Regression Line VS Actual Story Point')

plt.show()
